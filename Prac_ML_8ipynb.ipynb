# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekjain060305-coder/vivek_ML_Practicals/blob/main/Prac_ML_8ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Vivek Jain
#
# Usn: CS23094
#
# Aim: To apply the principle componet analysis for dimensionally reduction and visualize the transformed feature space

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
iris =load_iris()
x = iris.data
y = iris.target

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

# %%
print("Explained Variance Ratio:",
      pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.72962445 0.22850762]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x_pca[:, 0], x_pca[:,1],c=y)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
# Out:
# Text(0, 0.5, 'Principal Component 2')

# %%
pca=PCA()
pca.fit(x_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.show()
