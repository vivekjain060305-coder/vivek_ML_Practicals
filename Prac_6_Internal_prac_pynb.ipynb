# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekjain060305-coder/vivek_ML_Practicals/blob/main/Prac_6_Internal_prac_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Vivek Jain
# USN : CS23094

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/ML_lab/IRIS.csv"

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


model = keras.Sequential([
    layers.Dense(units=64, activation='relu', input_shape=(X_train_scaled.shape[1],)), # Use X_train_scaled shape
    layers.Dropout(0.2),
    layers.Dense(units=32, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(units=3, activation='softmax') # Output layer for multi-class classification (3 Iris species)
])


model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])


model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ...

# %%
history = model.fit(
    X_train_scaled, y_train_encoded, # Use scaled features and encoded labels
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

print("\nModel training complete.")
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9167 - loss: 0.2392 - val_accuracy: 0.9048 - val_loss: 0.2641
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9405 - loss: 0.2259 - val_accuracy: 0.9048 - val_loss: 0.2590
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9286 - loss: 0.2324 - val_accuracy: 0.9048 - val_loss: 0.2540
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9405 - loss: 0.2111 - val_accuracy: 0.9048 - val_loss: 0.2489
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9286 - loss: 0.1988 - val_accuracy: 0.9048 - val_loss: 0.2455
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9286 - loss: 0.2188 - val_accuracy: 0.9048 - val_loss: 0.2415
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9524 - loss: 0.2173 - val_accuracy: 0.9048 - val_loss: 0.2365
# Epoch 8/50
# ...

# %%
import numpy as np


loss_model, accuracy_model = model.evaluate(X_test_scaled, y_test_encoded, verbose=0)

print(f"\nModel Test Loss: {loss_model:.4f}")
print(f"Model Test Accuracy: {accuracy_model:.4f}")


y_pred_proba_model = model.predict(X_test_scaled)
y_pred_model = np.argmax(y_pred_proba_model, axis=1)


y_test_decoded_model = label_encoder.inverse_transform(y_test_encoded)
y_pred_decoded_model = label_encoder.inverse_transform(y_pred_model)


print("\nSample Predictions (Model) vs True Labels:")
for i in range(10):
    print(f"Predicted: {y_pred_decoded_model[i]}, True: {y_test_decoded_model[i]}")
# Out:
# Model Test Loss: 0.1978
# Model Test Accuracy: 0.9111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# Sample Predictions (Model) vs True Labels:
# Predicted: Iris-versicolor, True: Iris-versicolor
# Predicted: Iris-setosa, True: Iris-setosa
# Predicted: Iris-virginica, True: Iris-virginica
# Predicted: Iris-versicolor, True: Iris-versicolor
# Predicted: Iris-versicolor, True: Iris-versicolor
# Predicted: Iris-setosa, True: Iris-setosa
# Predicted: Iris-versicolor, True: Iris-versicolor
# Predicted: Iris-virginica, True: Iris-virginica
# Predicted: Iris-versicolor, True: Iris-versicolor
# Predicted: Iris-versicolor, True: Iris-versicolor

# %%
import numpy as np


loss, accuracy = ann.evaluate(X_test_scaled, y_test_encoded, verbose=0)

print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")


y_pred_proba = ann.predict(X_test_scaled)
y_pred = np.argmax(y_pred_proba, axis=1)


y_test_decoded = label_encoder.inverse_transform(y_test_encoded)
y_pred_decoded = label_encoder.inverse_transform(y_pred)


print("\nSample Predictions vs True Labels:")
for i in range(10):
    print(f"Predicted: {y_pred_decoded[i]}, True: {y_test_decoded[i]}")
# Out:
# Test Loss: 0.3475
# Test Accuracy: 0.8889
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#
# Sample Predictions vs True Labels:
# Predicted: Iris-virginica, True: Iris-versicolor
# Predicted: Iris-setosa, True: Iris-setosa
# Predicted: Iris-virginica, True: Iris-virginica
# Predicted: Iris-virginica, True: Iris-versicolor
# Predicted: Iris-virginica, True: Iris-versicolor
# Predicted: Iris-setosa, True: Iris-setosa
# Predicted: Iris-versicolor, True: Iris-versicolor
# Predicted: Iris-virginica, True: Iris-virginica
# Predicted: Iris-versicolor, True: Iris-versicolor
# Predicted: Iris-versicolor, True: Iris-versicolor

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")


x_train_processed = x_train.copy()
x_test_processed = x_test.copy()

print("\nShape of processed x_train:", x_train_processed.shape)
print("Shape of processed x_test:", x_test_processed.shape)
# Out:
# Shape of x_train: (120, 4)
# Shape of x_test: (30, 4)
# Shape of y_train: (120,)
# Shape of y_test: (30,)
#
# Shape of processed x_train: (120, 4)
# Shape of processed x_test: (30, 4)

# %%
from sklearn.metrics import accuracy_score
from google.colab import drive

# %%
df = pd.read_csv(path)

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
df.columns
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
x = df.drop('species', axis=1)
y = df['species']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (120, 4)
# Shape of x_test: (30, 4)
# Shape of y_train: (120,)
# Shape of y_test: (30,)

# %%
# x = pd.get_dummies(x, dtype=int)

# %%
x.shape
# Out:
# (150, 4)

# %%
df = pd.read_csv(path)
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.iloc[3:,:,]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
df = df.iloc[3:]

# %%
df.shape
# Out:
# (147, 5)

# %%
df = df.iloc[:, 3:]

# %%
df.shape
# Out:
# (147, 2)

# %%
# x = pd.get_dummies(x, dtype=int)

# %%
df.shape
# Out:
# (147, 2)

# %%
df.shape
# Out:
# (147, 2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd


x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7, test_size=0.3, random_state=42)


label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)


x_train_processed_for_scaling = x_train
x_test_processed_for_scaling = x_test

print(f"Shape of x_train after preprocessing: {x_train_processed_for_scaling.shape}")
print(f"Shape of x_test after preprocessing: {x_test_processed_for_scaling.shape}")
print(f"Shape of y_train_encoded: {y_train_encoded.shape}")
print(f"Shape of y_test_encoded: {y_test_encoded.shape}")
print(f"Encoded classes: {label_encoder.classes_}")
# Out:
# Shape of x_train after preprocessing: (105, 4)
# Shape of x_test after preprocessing: (45, 4)
# Shape of y_train_encoded: (105,)
# Shape of y_test_encoded: (45,)
# Encoded classes: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train_processed_for_scaling)
X_test_scaled = scaler.transform(x_test_processed_for_scaling)

print(f"Shape of X_train_scaled: {X_train_scaled.shape}")
print(f"Shape of X_test_scaled: {X_test_scaled.shape}")
# Out:
# Shape of X_train_scaled: (105, 4)
# Shape of X_test_scaled: (45, 4)

# %%
ann = tf.keras.models.Sequential()

# %%
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann.add(tf.keras.layers.Dense(units=3, activation='softmax')) # Changed for multi-class Iris classification

# %%
ann.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy']) # Changed loss for integer-encoded multi-class labels

# %%
ann.fit(X_train_scaled, y_train_encoded, batch_size = 32, epochs = 100) # Use encoded y_train
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4762 - loss: 1.0698
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4762 - loss: 1.0563
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4762 - loss: 1.0439
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5048 - loss: 1.0311
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5238 - loss: 1.0185
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5429 - loss: 1.0076
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5524 - loss: 0.9949
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5619 - loss: 0.9841
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5810 - loss: 0.9729
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5810 - loss: 0.9623
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5905 - loss: 0.9517
# Epoch 12/100
# ...
